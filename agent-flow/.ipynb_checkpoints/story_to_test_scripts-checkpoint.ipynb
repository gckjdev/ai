# %%
# Copyright (c) Microsoft. All rights reserved.

import asyncio
import logging

import semantic_kernel as sk
import semantic_kernel.connectors.ai.open_ai as sk_oai
from semantic_kernel.contents.chat_history import ChatHistory
from semantic_kernel.utils.settings import azure_openai_settings_from_dot_env_as_dict
import sys

script_name = sys.argv[0]

logging.basicConfig(level=logging.WARNING)

kernel = sk.Kernel()

service_id = "chat-gpt"
chat_service = sk_oai.AzureChatCompletion(
    service_id=service_id, **azure_openai_settings_from_dot_env_as_dict(include_api_version=True)
)
kernel.add_service(chat_service)

# note: using plugins from the code plugin folder
plugins_directory = "./plugins"
code_plugin = kernel.import_plugin_from_prompt_directory(plugins_directory, "CodePlugin")

feature_to_testcase_function = code_plugin["FeatureToTestCase"]
optimize_testcase_function = code_plugin["OptimizeTestCase"]
more_testcase_function = code_plugin["MoreTestCase"]
testcase_to_robot_framework_function = code_plugin["TestCaseToRobotFramework"]

print(f"Test Boost AI:> May I help you?")

async def chat() -> bool:
    try:
        user_input = input("User:> ")
    except KeyboardInterrupt:
        print("\n\nExiting chat...")
        return False
    except EOFError:
        print("\n\nExiting chat...")
        return False

    if user_input == "exit":
        print("\n\nExiting chat...")
        return False

    stream = True  # not used
    if stream:
        
        history = ChatHistory()
        answer = await kernel.invoke(feature_to_testcase_function, sk.KernelArguments(input=user_input), chat_history=history)
        print(f"Test Boost AI:> {answer}")        
        print("\n")
        print(f"Test Boost AI:> keep thinking......")        
        
        history = ChatHistory()
        answer = await kernel.invoke(optimize_testcase_function, sk.KernelArguments(input=answer), chat_history=history)
        print(f"Test Boost AI:> {answer}")        
        print("\n")
        print(f"Test Boost AI:> keep thinking......")        

        history = ChatHistory()
        answer = await kernel.invoke(more_testcase_function, sk.KernelArguments(input=answer), chat_history=history)
        print(f"Test Boost AI:> {answer}")        
        print("\n")
        print(f"Test Boost AI:> keep thinking......")        

        history = ChatHistory()
        answer = await kernel.invoke(testcase_to_robot_framework_function, sk.KernelArguments(input=answer), chat_history=history)
        print(f"Test Boost AI:> {answer}")        
        print("\n")

    return True

async def main() -> None:
    chatting = True
    while chatting:
        chatting = await chat()

await main()
# Out:
# Test Boost AI:> May I help you?
# User:>  As a brand manager, I want to get alerts whenever a reseller advertises our products below agreed-upon prices so that I can quickly take action to protect our brand.
# Test Boost AI:> Feature: Reseller Price Alert System
#
# Scenario: Receive alert when a reseller advertises products below agreed-upon prices
# Given a brand manager is logged into the price monitoring system
# And the system has the agreed-upon prices for all products
# When a reseller advertises a product below the agreed-upon price
# Then the system should trigger an alert to the brand manager
# And the alert should contain the product name, reseller name, and advertised price
# And the alert should be sent via the brand manager's preferred method of communication.
#
#
# Test Boost AI:> keep thinking......
# Test Boost AI:> Feature: Reseller Price Alert System
#
# Scenario: Receive alert when a reseller advertises products below agreed-upon prices
# Given a brand manager named "John" is logged into the price monitoring system
# And the system has the agreed-upon price of $100 for product "XYZ"
# When a reseller named "Reseller1" advertises product "XYZ" at $90
# Then the system should trigger an alert to "John"
# And the alert should contain the product name "XYZ", reseller name "Reseller1", and advertised price $90
# And the alert should be sent via "John's" preferred method of communication, which is email.
#
#
# Test Boost AI:> keep thinking......
# Test Boost AI:> #Feature: Reseller Price Alert System
#
# Scenario: Receive alert when multiple resellers advertise products below agreed-upon prices
# Given a brand manager named "John" is logged into the price monitoring system
# And the system has the agreed-upon price of $100 for product "XYZ"
# When a reseller named "Reseller1" advertises product "XYZ" at $90
# And a reseller named "Reseller2" advertises product "XYZ" at $95
# Then the system should trigger an alert to "John"
# And the alert should contain the product name "XYZ", reseller names "Reseller1" and "Reseller2", and advertised prices $90 and $95 respectively
# And the alert should be sent via "John's" preferred method of communication, which is email.
#
# Scenario: No alert when a reseller advertises products at or above agreed-upon prices
# Given a brand manager named "John" is logged into the price monitoring system
# And the system has the agreed-upon price of $100 for product "XYZ"
# When a reseller named "Reseller1" advertises product "XYZ" at $100
# Then the system should not trigger an alert to "John"
#
# Scenario: Receive alert when a reseller advertises multiple products below agreed-upon prices
# Given a brand manager named "John" is logged into the price monitoring system
# And the system has the agreed-upon price of $100 for product "XYZ" and $200 for product "ABC"
# When a reseller named "Reseller1" advertises product "XYZ" at $90 and product "ABC" at $190
# Then the system should trigger an alert to "John"
# And the alert should contain the product names "XYZ" and "ABC", reseller name "Reseller1", and advertised prices $90 and $190 respectively
# And the alert should be sent via "John's" preferred method of communication, which is email.
#
# Scenario: Receive alert when a reseller advertises products below agreed-upon prices in different currency
# Given a brand manager named "John" is logged into the price monitoring system
# And the system has the agreed-upon price of $100 for product "XYZ"
# When a reseller named "Reseller1" advertises product "XYZ" at £70 (assuming £1 = $1.3)
# Then the system should trigger an alert to "John"
# And the alert should contain the product name "XYZ", reseller name "Reseller1", and advertised price £70
# And the alert should be sent via "John's" preferred method of communication, which is email.
#
#
# Test Boost AI:> keep thinking......
# Test Boost AI:> Output:
#
# ```python
# from robot.api.deco import keyword
# from robot.libraries.BuiltIn import BuiltIn
#
# class PriceAlertSystemTest:
#
#     @keyword("Brand manager named ${name} is logged into the price monitoring system")
#     def brand_manager_logged_in(self, name):
#         # Code to verify if the brand manager is logged in
#         pass
#
#     @keyword("System has the agreed-upon price of ${price} for product ${product}")
#     def agreed_upon_price(self, price, product):
#         # Code to verify the agreed-upon price for the product
#         pass
#
#     @keyword("Reseller named ${reseller} advertises product ${product} at ${price}")
#     def reseller_advertises_product(self, reseller, product, price):
#         # Code to simulate the reseller advertising a product
#         pass
#
#     @keyword("System should trigger an alert to ${name}")
#     def system_triggers_alert(self, name):
#         # Code to verify if the system triggers an alert
#         pass
#
#     @keyword("Alert should contain the product name ${product}, reseller names ${reseller}, and advertised prices ${price} respectively")
#     def alert_contains_info(self, product, reseller, price):
#         # Code to verify if the alert contains the correct information
#         pass
#
#     @keyword("Alert should be sent via ${name}'s preferred method of communication, which is email")
#     def alert_sent_via_email(self, name):
#         # Code to verify if the alert is sent via email
#         pass
#
#     @keyword("System should not trigger an alert to ${name}")
#     def system_not_trigger_alert(self, name):
#         # Code to verify if the system does not trigger an alert
#         pass
#
#     @keyword("Alert should contain the product names ${product1} and ${product2}, reseller name ${reseller}, and advertised prices ${price1} and ${price2} respectively")
#     def alert_contains_multiple_product_info(self, product1, product2, reseller, price1, price2):
#         # Code to verify if the alert contains the correct information for multiple products
#         pass
#
#     @keyword("Reseller named ${reseller} advertises product ${product} at £${price} (assuming £1 = $1.3)")
#     def reseller_advertises_product_in_pound(self, reseller, product, price):
#         # Code to simulate the reseller advertising a product in a different currency
#         pass
#
#     @keyword("Alert should contain the product name ${product}, reseller name ${reseller}, and advertised price £${price}")
#     def alert_contains_info_in_pound(self, product, reseller, price):
#         # Code to verify if the alert contains the correct information in a different currency
#         pass
# ```
#
# Please note that the actual implementation of these keywords would depend on the specifics of the system under test.
