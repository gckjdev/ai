# %%
# Copyright (c) Microsoft. All rights reserved.

import asyncio
import logging

import semantic_kernel as sk
import semantic_kernel.connectors.ai.open_ai as sk_oai
from semantic_kernel.contents.chat_history import ChatHistory
from semantic_kernel.utils.settings import azure_openai_settings_from_dot_env_as_dict
import sys

script_name = sys.argv[0]

logging.basicConfig(level=logging.WARNING)

kernel = sk.Kernel()

service_id = "chat-gpt"
chat_service = sk_oai.AzureChatCompletion(
    service_id=service_id, **azure_openai_settings_from_dot_env_as_dict(include_api_version=True)
)
kernel.add_service(chat_service)

# note: using plugins from the code plugin folder
plugins_directory = "./plugins"
code_plugin = kernel.import_plugin_from_prompt_directory(plugins_directory, "CodePlugin")

feature_to_testcase_function = code_plugin["FeatureToTestCase"]
optimize_testcase_function = code_plugin["OptimizeTestCase"]
more_testcase_function = code_plugin["MoreTestCase"]
testcase_to_robot_framework_function = code_plugin["TestCaseToRobotFramework"]

print(f"Test Boost AI:> May I help you?")

async def chat() -> bool:
    try:
        user_input = input("User:> ")
    except KeyboardInterrupt:
        print("\n\nExiting chat...")
        return False
    except EOFError:
        print("\n\nExiting chat...")
        return False

    if user_input == "exit":
        print("\n\nExiting chat...")
        return False

    stream = True  # not used
    if stream:
        
        history = ChatHistory()
        answer = await kernel.invoke(feature_to_testcase_function, sk.KernelArguments(input=user_input), chat_history=history)
        print(f"Test Boost AI:> {answer}")        
        print("\n")
        print(f"Test Boost AI:> keep thinking......")        
        
        history = ChatHistory()
        answer = await kernel.invoke(optimize_testcase_function, sk.KernelArguments(input=answer), chat_history=history)
        print(f"Test Boost AI:> {answer}")        
        print("\n")
        print(f"Test Boost AI:> keep thinking......")        

        history = ChatHistory()
        answer = await kernel.invoke(more_testcase_function, sk.KernelArguments(input=answer), chat_history=history)
        print(f"Test Boost AI:> {answer}")        
        print("\n")
        print(f"Test Boost AI:> keep thinking......")        

        history = ChatHistory()
        answer = await kernel.invoke(testcase_to_robot_framework_function, sk.KernelArguments(input=answer), chat_history=history)
        print(f"Test Boost AI:> {answer}")        
        print("\n")

    return True

async def main() -> None:
    chatting = True
    while chatting:
        chatting = await chat()

await main()
# Out:
# Test Boost AI:> May I help you?
# User:>  As a brand manager, I want to get alerts whenever a reseller advertises our products below agreed-upon prices so that I can quickly take action to protect our brand.
# Test Boost AI:> Feature: Reseller Price Alert System
#
# Scenario: Receive alert when reseller advertises products below agreed-upon prices
# Given a brand manager is logged into the price monitoring system
# And the system has a list of agreed-upon prices for all products
# When a reseller advertises a product below the agreed-upon price
# Then the system should trigger an alert to the brand manager
# And the alert should contain the product name, reseller name, advertised price, and agreed-upon price
# And the brand manager should be able to quickly take action to protect the brand.
#
#
# Test Boost AI:> keep thinking......
# Test Boost AI:> Feature: Reseller Price Alert System
#
# Scenario: Receive alert when reseller advertises products below agreed-upon prices
# Given a brand manager named "John" is logged into the price monitoring system
# And the system has a list of agreed-upon prices for all products
# And a product named "Product A" has an agreed-upon price of $100
# And a reseller named "Reseller X" is registered in the system
# When "Reseller X" advertises "Product A" at a price of $90
# Then the system should trigger an alert to "John"
# And the alert should contain the product name as "Product A", reseller name as "Reseller X", advertised price as $90, and agreed-upon price as $100
# And "John" should be able to quickly take action to protect the brand.
#
#
# Test Boost AI:> keep thinking......
# Test Boost AI:> #Feature: Reseller Price Alert System
#
# Scenario: Receive alert when reseller advertises multiple products below agreed-upon prices
# Given a brand manager named "John" is logged into the price monitoring system
# And the system has a list of agreed-upon prices for all products
# And a product named "Product A" has an agreed-upon price of $100
# And a product named "Product B" has an agreed-upon price of $200
# And a reseller named "Reseller X" is registered in the system
# When "Reseller X" advertises "Product A" at a price of $90
# And "Reseller X" advertises "Product B" at a price of $180
# Then the system should trigger an alert to "John"
# And the alert should contain the product names as "Product A" and "Product B", reseller name as "Reseller X", advertised prices as $90 and $180, and agreed-upon prices as $100 and $200
# And "John" should be able to quickly take action to protect the brand.
#
# Scenario: No alert when reseller advertises products at or above agreed-upon prices
# Given a brand manager named "John" is logged into the price monitoring system
# And the system has a list of agreed-upon prices for all products
# And a product named "Product A" has an agreed-upon price of $100
# And a reseller named "Reseller X" is registered in the system
# When "Reseller X" advertises "Product A" at a price of $100
# Then the system should not trigger an alert to "John"
#
# Scenario: Receive alert when multiple resellers advertise products below agreed-upon prices
# Given a brand manager named "John" is logged into the price monitoring system
# And the system has a list of agreed-upon prices for all products
# And a product named "Product A" has an agreed-upon price of $100
# And a reseller named "Reseller X" is registered in the system
# And a reseller named "Reseller Y" is registered in the system
# When "Reseller X" advertises "Product A" at a price of $90
# And "Reseller Y" advertises "Product A" at a price of $95
# Then the system should trigger an alert to "John"
# And the alert should contain the product name as "Product A", reseller names as "Reseller X" and "Reseller Y", advertised prices as $90 and $95, and agreed-upon price as $100
# And "John" should be able to quickly take action to protect the brand.
#
#
# Test Boost AI:> keep thinking......
# Test Boost AI:> Output:
#
# ```python
# from robot.api import TestSuite
# from robot.api.deco import keyword
# from robot.libraries.BuiltIn import BuiltIn
#
# class PriceAlertSystem:
#     def __init__(self):
#         self.system = PriceMonitoringSystem()
#         self.manager = None
#         self.resellers = {}
#         self.products = {}
#
#     @keyword("Brand manager named ${name} is logged in")
#     def login_manager(self, name):
#         self.manager = self.system.login(name)
#
#     @keyword("System has a list of agreed-upon prices for all products")
#     def set_prices(self):
#         self.products = self.system.get_product_prices()
#
#     @keyword("Product named ${product} has an agreed-upon price of ${price}")
#     def set_product_price(self, product, price):
#         self.products[product] = price
#
#     @keyword("Reseller named ${name} is registered in the system")
#     def register_reseller(self, name):
#         self.resellers[name] = Reseller(name)
#
#     @keyword("${reseller} advertises ${product} at a price of ${price}")
#     def reseller_advertises_product(self, reseller, product, price):
#         self.resellers[reseller].advertise(product, price)
#
#     @keyword("System should trigger an alert to ${manager}")
#     def check_alert_triggered(self, manager):
#         alerts = self.system.get_alerts(manager)
#         assert len(alerts) > 0, "No alerts triggered"
#
#     @keyword("System should not trigger an alert to ${manager}")
#     def check_no_alert_triggered(self, manager):
#         alerts = self.system.get_alerts(manager)
#         assert len(alerts) == 0, "Alerts were triggered"
#
#     @keyword("Alert should contain the product names as ${products}, reseller name as ${reseller}, advertised prices as ${advertised_prices}, and agreed-upon prices as ${agreed_prices}")
#     def check_alert_content(self, products, reseller, advertised_prices, agreed_prices):
#         alerts = self.system.get_alerts(self.manager)
#         for alert in alerts:
#             assert alert['products'] == products, "Incorrect products in alert"
#             assert alert['reseller'] == reseller, "Incorrect reseller in alert"
#             assert alert['advertised_prices'] == advertised_prices, "Incorrect advertised prices in alert"
#             assert alert['agreed_prices'] == agreed_prices, "Incorrect agreed-upon prices in alert"
#
#     @keyword("${manager} should be able to quickly take action to protect the brand")
#     def check_manager_action(self, manager):
#         assert self.system.can_take_action(manager), "Manager cannot take action"
#
# # Create a test suite
# suite = TestSuite('Reseller Price Alert System')
#
# # Add keywords from the PriceAlertSystem class
# suite.resource.imports.library('PriceAlertSystem')
#
# # Add test cases
# suite.test_case('Receive alert when reseller advertises multiple products below agreed-upon prices')
# suite.test_case('No alert when reseller advertises products at or above agreed-upon prices')
# suite.test_case('Receive alert when multiple resellers advertise products below agreed-upon prices')
#
# # Run the suite
# suite.run(output='output.xml')
# ```
#
# Please note that the above script assumes the existence of a `PriceMonitoringSystem` class and a `Reseller` class, which are not defined in the provided context. These classes should be implemented according to the specific requirements of the system under test.
